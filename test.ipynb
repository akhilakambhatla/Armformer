# %%
# !python ../../../../../../opt/mmsegmentation/tools/test.py segformer_mit-b0_8xb2-160k_methane-512x512.py work_dirs/best_mIoU_iter_160000.pth --work-dir work_dirs --show-dir inference
# Out:
# 03/20 02:18:03 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: win32
#     Python: 3.10.13 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:24:38) [MSC v.1916 64 bit (AMD64)]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 968765774
#     GPU 0: NVIDIA GeForce RTX 3090
#     CUDA_HOME: C:/Program Files/NVIDIA GPU Computing Toolkit/CUDA\v11.6
#     NVCC: Cuda compilation tools, release 11.6, V11.6.55
#     MSVC: Microsoft (R) C/C++ Optimizing Compiler Version 19.29.30137 for x64
#     GCC: n/a
#     PyTorch: 2.2.0
#     PyTorch compiling details: PyTorch built with:
#   - C++ Version: 201703
#   - MSVC 192930151
#   - Intel(R) Math Kernel Library Version 2020.0.2 Product Build 20200624 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.2 (Git Hash 2dc95a2ad0841e29db8b22fbccaf3e5da7992b01)
#   - OpenMP 2019
#   - LAPACK is enabled (usually provided by MKL)
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_90,code=sm_90;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.7
#   - Magma 2.5.4
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=C:/cb/pytorch_1000000000000/work/tmp_bin/sccache-cl.exe, CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /Zc:__cplusplus /bigobj /FS /utf-8 -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE /wd4624 /wd4068 /wd4067 /wd4267 /wd4661 /wd4717 /wd4244 /wd4804 /wd4273, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.2.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.17.0
#     OpenCV: 4.9.0
#     MMEngine: 0.10.3
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 968765774
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 03/20 02:18:03 - mmengine - INFO - Config:
# checkpoint = 'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segformer/mit_b0_20220624-7e0fe6dd.pth'
# crop_size = (
#     512,
#     512,
# )
# data_preprocessor = dict(
#     bgr_to_rgb=True,
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     pad_val=0,
#     seg_pad_val=255,
#     size=(
#         512,
#         512,
#     ),
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     type='SegDataPreProcessor')
# data_root = '../../../../data/V7/'
# dataset_type = 'MethaneDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         by_epoch=False,
#         interval=16000,
#         max_keep_ckpts=2,
#         save_best='mIoU',
#         type='CheckpointHook'),
#     logger=dict(interval=50, log_metric_by_epoch=False, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(draw=True, type='SegVisualizationHook'))
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# img_ratios = [
#     0.5,
#     0.75,
#     1.0,
#     1.25,
#     1.5,
#     1.75,
# ]
# img_scale = (
#     640,
#     480,
# )
# launcher = 'none'
# load_from = 'work_dirs/best_mIoU_iter_160000.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=False)
# model = dict(
#     backbone=dict(
#         attn_drop_rate=0.0,
#         drop_path_rate=0.1,
#         drop_rate=0.0,
#         embed_dims=32,
#         in_channels=3,
#         init_cfg=dict(
#             checkpoint=
#             'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segformer/mit_b0_20220624-7e0fe6dd.pth',
#             type='Pretrained'),
#         mlp_ratio=4,
#         num_heads=[
#             1,
#             2,
#             5,
#             8,
#         ],
#         num_layers=[
#             2,
#             2,
#             2,
#             2,
#         ],
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         patch_sizes=[
#             7,
#             3,
#             3,
#             3,
#         ],
#         qkv_bias=True,
#         sr_ratios=[
#             8,
#             4,
#             2,
#             1,
#         ],
#         type='MixVisionTransformer'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             512,
#             512,
#         ),
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='SegDataPreProcessor'),
#     decode_head=dict(
#         align_corners=False,
#         channels=256,
#         dropout_ratio=0.1,
#         in_channels=[
#             32,
#             64,
#             160,
#             256,
#         ],
#         in_index=[
#             0,
#             1,
#             2,
#             3,
#         ],
#         loss_decode=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#         norm_cfg=dict(requires_grad=True, type='SyncBN'),
#         num_classes=11,
#         type='SegformerHead'),
#     pretrained=None,
#     test_cfg=dict(mode='whole'),
#     train_cfg=dict(),
#     type='EncoderDecoder')
# norm_cfg = dict(requires_grad=True, type='SyncBN')
# optim_wrapper = dict(
#     optimizer=dict(
#         betas=(
#             0.9,
#             0.999,
#         ), lr=6e-05, type='AdamW', weight_decay=0.01),
#     paramwise_cfg=dict(
#         custom_keys=dict(
#             head=dict(lr_mult=10.0),
#             norm=dict(decay_mult=0.0),
#             pos_block=dict(decay_mult=0.0))),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=1500, start_factor=1e-06,
#         type='LinearLR'),
#     dict(
#         begin=1500,
#         by_epoch=False,
#         end=160000,
#         eta_min=0.0,
#         power=1.0,
#         type='PolyLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(
#             img_path='test/images', seg_map_path='test/mmseg_masks'),
#         data_root='../../../../data/V7/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 640,
#                 480,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='MethaneDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#         'mFscore',
#     ], type='IoUMetric')
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         640,
#         480,
#     ), type='Resize'),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs'),
# ]
# train_cfg = dict(
#     max_iters=160000, type='IterBasedTrainLoop', val_interval=16000)
# train_dataloader = dict(
#     batch_size=2,
#     dataset=dict(
#         data_prefix=dict(
#             img_path='train/images', seg_map_path='train/mmseg_masks'),
#         data_root='../../../../data/V7/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     0.5,
#                     2.0,
#                 ),
#                 scale=(
#                     640,
#                     480,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 cat_max_ratio=0.75, crop_size=(
#                     512,
#                     512,
#                 ), type='RandomCrop'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs'),
#         ],
#         type='MethaneDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='InfiniteSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             0.5,
#             2.0,
#         ),
#         scale=(
#             640,
#             480,
#         ),
#         type='RandomResize'),
#     dict(cat_max_ratio=0.75, crop_size=(
#         512,
#         512,
#     ), type='RandomCrop'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs'),
# ]
# tta_model = dict(type='SegTTAModel')
# tta_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         transforms=[
#             [
#                 dict(keep_ratio=True, scale_factor=0.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=0.75, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.0, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.25, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.75, type='Resize'),
#             ],
#             [
#                 dict(direction='horizontal', prob=1.0, type='RandomFlip'),
#             ],
#             [
#                 dict(type='LoadAnnotations'),
#             ],
#             [
#                 dict(type='PackSegInputs'),
#             ],
#         ],
#         type='TestTimeAug'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(
#             img_path='validation/images',
#             seg_map_path='validation/mmseg_masks'),
#         data_root='../../../../data/V7/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 640,
#                 480,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='MethaneDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#         'mFscore',
#     ], type='IoUMetric')
# vis_backends = [
#     dict(save_dir='work_dirs', type='LocalVisBackend'),
#     dict(type='TensorboardVisBackend'),
#     dict(
#         init_kwargs=dict(
#             entity='toqi',
#             group='segformer',
#             name='Exp_3_DV7_mIoU',
#             project='methane-segmentation'),
#         type='WandbVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     save_dir='inference',
#     type='SegLocalVisualizer',
#     vis_backends=[
#         dict(save_dir='work_dirs', type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(
#             init_kwargs=dict(
#                 entity='toqi',
#                 group='segformer',
#                 name='Exp_3_DV7_mIoU',
#                 project='methane-segmentation'),
#             type='WandbVisBackend'),
#     ])
# work_dir = 'work_dirs'
#
# 03/20 02:18:12 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 03/20 02:18:12 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 03/20 02:18:12 - mmengine - WARNING - The prefix is not set in metric class IoUMetric.
# Loads checkpoint
# |     60     | 86.92 | 91.32 |  93.0  |   94.74   | 91.32  |
# |     70     | 89.53 | 95.08 | 94.47  |   93.87   | 95.08  |
# |     80     | 88.72 | 94.86 | 94.02  |    93.2   | 94.86  |
# |     90     | 87.59 | 91.96 | 93.38  |   94.84   | 91.96  |
# |    100     | 84.63 | 88.05 | 91.68  |   95.61   | 88.05  |
# +------------+-------+-------+--------+-----------+--------+
# 03/20 02:19:09 - mmengine - INFO - Iter(test) [956/956]    aAcc: 99.3200  mIoU: 85.3700  mAcc: 90.2200  mFscore: 91.9400  mPrecision: 93.8600  mRecall: 90.2200  data_time: 0.0432  time: 0.0587
# wandb: Currently logged in as: toqi. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.16.3
# wandb: Run data is saved locally in inference\vis_data\wandb\run-20240320_021807-p5qphs6u
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Exp_3_DV7_mIoU
# wandb:  View project at https://wandb.ai/toqi/methane-segmentation
# wandb:  View run at https://wandb.ai/toqi/methane-segmentation/runs/p5qphs6u
# d:\toqi\opt\mmsegmentation\mmseg\models\builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# d:\toqi\opt\mmsegmentation\mmseg\models\losses\cross_entropy_loss.py:250: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# wandb: - 3.271 MB of 3.271 MB uploaded (0.003 MB deduped)
# wandb: \ 3.271 MB of 3.271 MB uploaded (0.003 MB deduped)
# wandb: | 3.336 MB of 3.360 MB uploaded (0.006 MB deduped)
# wandb: / 3.336 MB of 3.360 MB uploaded (0.006 MB deduped)
# wandb: - 3.360 MB of 3.360 MB uploaded (0.006 MB deduped)
# wandb:
# wandb:  View run Exp_3_DV7_mIoU at: https://wandb.ai/toqi/methane-segmentation/runs/p5qphs6u
# wandb:  View job at https://wandb.ai/toqi/methane-segmentation/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjEzOTIwNDUxMQ==/version_details/v61
# wandb: Synced 5 W&B file(s), 19 media file(s), 7 artifact file(s) and 0 other file(s)
# wandb: Find logs at: inference\vis_data\wandb\run-20240320_021807-p5qphs6u\logs

# %%
# !python ../../../../../../opt/mmsegmentation/tools/test.py \
segformer_mit-b0_8xb2-160k_methane-512x512.py \
work_dirs/best_mIoU_iter_160000.pth \
--out results/test_images \
--work-dir work_dirs
# Out:
# 03/20 02:19:26 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: win32
#     Python: 3.10.13 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:24:38) [MSC v.1916 64 bit (AMD64)]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 2068909248
#     GPU 0: NVIDIA GeForce RTX 3090
#     CUDA_HOME: C:/Program Files/NVIDIA GPU Computing Toolkit/CUDA\v11.6
#     NVCC: Cuda compilation tools, release 11.6, V11.6.55
#     MSVC: Microsoft (R) C/C++ Optimizing Compiler Version 19.29.30137 for x64
#     GCC: n/a
#     PyTorch: 2.2.0
#     PyTorch compiling details: PyTorch built with:
#   - C++ Version: 201703
#   - MSVC 192930151
#   - Intel(R) Math Kernel Library Version 2020.0.2 Product Build 20200624 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.2 (Git Hash 2dc95a2ad0841e29db8b22fbccaf3e5da7992b01)
#   - OpenMP 2019
#   - LAPACK is enabled (usually provided by MKL)
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_90,code=sm_90;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.7
#   - Magma 2.5.4
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=C:/cb/pytorch_1000000000000/work/tmp_bin/sccache-cl.exe, CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /Zc:__cplusplus /bigobj /FS /utf-8 -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE /wd4624 /wd4068 /wd4067 /wd4267 /wd4661 /wd4717 /wd4244 /wd4804 /wd4273, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.2.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.17.0
#     OpenCV: 4.9.0
#     MMEngine: 0.10.3
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 2068909248
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 03/20 02:19:26 - mmengine - INFO - Config:
# checkpoint = 'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segformer/mit_b0_20220624-7e0fe6dd.pth'
# crop_size = (
#     512,
#     512,
# )
# data_preprocessor = dict(
#     bgr_to_rgb=True,
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     pad_val=0,
#     seg_pad_val=255,
#     size=(
#         512,
#         512,
#     ),
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     type='SegDataPreProcessor')
# data_root = '../../../../data/V7/'
# dataset_type = 'MethaneDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         by_epoch=False,
#         interval=16000,
#         max_keep_ckpts=2,
#         save_best='mIoU',
#         type='CheckpointHook'),
#     logger=dict(interval=50, log_metric_by_epoch=False, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(draw=True, type='SegVisualizationHook'))
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# img_ratios = [
#     0.5,
#     0.75,
#     1.0,
#     1.25,
#     1.5,
#     1.75,
# ]
# img_scale = (
#     640,
#     480,
# )
# launcher = 'none'
# load_from = 'work_dirs/best_mIoU_iter_160000.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=False)
# model = dict(
#     backbone=dict(
#         attn_drop_rate=0.0,
#         drop_path_rate=0.1,
#         drop_rate=0.0,
#         embed_dims=32,
#         in_channels=3,
#         init_cfg=dict(
#             checkpoint=
#             'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segformer/mit_b0_20220624-7e0fe6dd.pth',
#             type='Pretrained'),
#         mlp_ratio=4,
#         num_heads=[
#             1,
#             2,
#             5,
#             8,
#         ],
#         num_layers=[
#             2,
#             2,
#             2,
#             2,
#         ],
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         patch_sizes=[
#             7,
#             3,
#             3,
#             3,
#         ],
#         qkv_bias=True,
#         sr_ratios=[
#             8,
#             4,
#             2,
#             1,
#         ],
#         type='MixVisionTransformer'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             512,
#             512,
#         ),
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='SegDataPreProcessor'),
#     decode_head=dict(
#         align_corners=False,
#         channels=256,
#         dropout_ratio=0.1,
#         in_channels=[
#             32,
#             64,
#             160,
#             256,
#         ],
#         in_index=[
#             0,
#             1,
#             2,
#             3,
#         ],
#         loss_decode=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#         norm_cfg=dict(requires_grad=True, type='SyncBN'),
#         num_classes=11,
#         type='SegformerHead'),
#     pretrained=None,
#     test_cfg=dict(mode='whole'),
#     train_cfg=dict(),
#     type='EncoderDecoder')
# norm_cfg = dict(requires_grad=True, type='SyncBN')
# optim_wrapper = dict(
#     optimizer=dict(
#         betas=(
#             0.9,
#             0.999,
#         ), lr=6e-05, type='AdamW', weight_decay=0.01),
#     paramwise_cfg=dict(
#         custom_keys=dict(
#             head=dict(lr_mult=10.0),
#             norm=dict(decay_mult=0.0),
#             pos_block=dict(decay_mult=0.0))),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=1500, start_factor=1e-06,
#         type='LinearLR'),
#     dict(
#         begin=1500,
#         by_epoch=False,
#         end=160000,
#         eta_min=0.0,
#         power=1.0,
#         type='PolyLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(
#             img_path='test/images', seg_map_path='test/mmseg_masks'),
#         data_root='../../../../data/V7/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 640,
#                 480,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='MethaneDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#         'mFscore',
#     ],
#     keep_results=True,
#     output_dir='results/test_images',
#     type='IoUMetric')
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         640,
#         480,
#     ), type='Resize'),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs'),
# ]
# train_cfg = dict(
#     max_iters=160000, type='IterBasedTrainLoop', val_interval=16000)
# train_dataloader = dict(
#     batch_size=2,
#     dataset=dict(
#         data_prefix=dict(
#             img_path='train/images', seg_map_path='train/mmseg_masks'),
#         data_root='../../../../data/V7/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     0.5,
#                     2.0,
#                 ),
#                 scale=(
#                     640,
#                     480,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 cat_max_ratio=0.75, crop_size=(
#                     512,
#                     512,
#                 ), type='RandomCrop'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs'),
#         ],
#         type='MethaneDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='InfiniteSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             0.5,
#             2.0,
#         ),
#         scale=(
#             640,
#             480,
#         ),
#         type='RandomResize'),
#     dict(cat_max_ratio=0.75, crop_size=(
#         512,
#         512,
#     ), type='RandomCrop'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs'),
# ]
# tta_model = dict(type='SegTTAModel')
# tta_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         transforms=[
#             [
#                 dict(keep_ratio=True, scale_factor=0.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=0.75, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.0, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.25, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.75, type='Resize'),
#             ],
#             [
#                 dict(direction='horizontal', prob=1.0, type='RandomFlip'),
#             ],
#             [
#                 dict(type='LoadAnnotations'),
#             ],
#             [
#                 dict(type='PackSegInputs'),
#             ],
#         ],
#         type='TestTimeAug'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(
#             img_path='validation/images',
#             seg_map_path='validation/mmseg_masks'),
#         data_root='../../../../data/V7/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 640,
#                 480,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='MethaneDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#         'mFscore',
#     ], type='IoUMetric')
# vis_backends = [
#     dict(save_dir='work_dirs', type='LocalVisBackend'),
#     dict(type='TensorboardVisBackend'),
#     dict(
#         init_kwargs=dict(
#             entity='toqi',
#             group='segformer',
#             name='Exp_3_DV7_mIoU',
#             project='methane-segmentation'),
#         type='WandbVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='SegLocalVisualizer',
#     vis_backends=[
#         dict(save_dir='work_dirs', type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(
#             init_kwargs=dict(
#                 entity='toqi',
#                 group='segformer',
#                 name='Exp_3_DV7_mIoU',
#                 project='methane-segmentation'),
#             type='WandbVisBackend'),
#     ])
# work_dir = 'work_dirs'
#
# 03/20 02:19:32 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 03/20 02:19:32 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 03/20 02:19:33 - mmengine - WARNING - The prefix is not set in metric class IoUMetric.
# Loads checkpoint by local backend from path: work_dirs/best_mIoU_iter_160000.pth
# 03/20 02:19:33 - mmengine - INFO - Load checkpoint from work_dirs/best_mIoU_iter_160000.pth
# 03/20 02:19:59 - mmengine - INFO - Iter(test) [ 50/956]    eta: 0:05:23  time: 0.0157  data_time: 0.0000  memory: 330
# 03/20 02:20:02 - mmengine - INFO - Iter(test) [100/956]    eta: 0:03:54  time: 0.0159  data_time: 0.0000  memory: 277
# 03/20 02:20:04 - mmengine - INFO - Iter(test) [150/956]    eta: 0:02:38  time: 0.0147  data_time: 0.0001  memory: 277
# 03/20 02:20:06 - mmengine - INFO - Iter(test) [200/956]    eta: 0:01:58  time: 0.0153  data_time: 0.0000  memory: 277
# 03/20 02:20:07 - mmengine - INFO - Iter(test) [250/956]    eta: 0:01:33  time: 0.0153  data_time: 0.0006  memory: 277
# 03/20 02:20:09 - mmengine - INFO - Iter(test) [300/956]    eta: 0:01:16  time: 0.0157  data_time: 0.0000  memory: 277
# 03/20 02:20:11 - mmengine - INFO - Iter(test) [350/956]    eta: 0:01:03  time: 0.0153  data_time: 0.0016  memory: 277
# 03/20 02:20:13 - mmengine - INFO - Iter(test) [400/956]    eta: 0:00:53  time: 0.0153  data_time: 0.0028  memory: 277
# 03/20 02:20:15 - mmengine - INFO - Iter(test) [450/956]    eta: 0:00:45  time: 0.0192  data_time: 0.0000  memory: 277
# 03/20 02:20:16 - mmengine - INFO - Iter(test) [500/956]    eta: 0:00:38  time: 0.0165  data_time: 0.0000  memory: 277
# 03/20 02:20:18 - mmengine - INFO - Iter(test) [550/956]    eta: 0:00:32  time: 0.0142  data_time: 0.0001  memory: 277
# 03/20 02:20:20 - mmengine - INFO - Iter(test) [600/956]    eta: 0:00:27  time: 0.0141  data_time: 0.0012  memory: 277
# 03/20 02:20:22 - mmengine - INFO - Iter(test) [650/956]    eta: 0:00:22  time: 0.0151  data_time: 0.0000  memory: 277
# 03/20 02:20:24 - mmengine - INFO - Iter(test) [700/956]    eta: 0:00:18  time: 0.0153  data_time: 0.0001  memory: 277
# 03/20 02:20:25 - mmengine - INFO - Iter(test) [750/956]    eta: 0:00:14  time: 0.0160  data_time: 0.0006  memory: 277
# 03/20 02:20:27 - mmengine - INFO - Iter(test) [800/956]    eta: 0:00:10  time: 0.0152  data_time: 0.0000  memory: 277
# 03/20 02:20:29 - mmengine - INFO - Iter(test) [850/956]    eta: 0:00:06  time: 0.0153  data_time: 0.0000  memory: 277
# 03/20 02:20:31 - mmengine - INFO - Iter(test) [900/956]    eta: 0:00:03  time: 0.0146  data_time: 0.0018  memory: 277
# 03/20 02:20:33 - mmengine - INFO - Iter(test) [950/956]    eta: 0:00:00  time: 0.0153  data_time: 0.0000  memory: 277
# 03/20 02:20:33 - mmengine - INFO - per class results:
# 03/20 02:20:33 - mmengine - INFO -
# +------------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  | Fscore | Precision | Recall |
# +------------+-------+-------+--------+-----------+--------+
# | background | 99.29 | 99.69 | 99.64  |    99.6   | 99.69  |
# |     10     | 67.83 | 76.67 | 80.83  |   85.47   | 76.67  |
# |     20     | 80.33 | 83.77 | 89.09  |   95.13   | 83.77  |
# |     30     | 84.39 | 87.09 | 91.53  |   96.45   | 87.09  |
# |     40     | 84.96 | 90.39 | 91.87  |   93.39   | 90.39  |
# |     50     | 84.91 | 93.54 | 91.84  |    90.2   | 93.54  |
# |     60     | 86.92 | 91.32 |  93.0  |   94.74   | 91.32  |
# |     70     | 89.53 | 95.08 | 94.47  |   93.88   | 95.08  |
# |     80     | 88.72 | 94.86 | 94.02  |    93.2   | 94.86  |
# |     90     | 87.58 | 91.96 | 93.38  |   94.84   | 91.96  |
# |    100     | 84.63 | 88.05 | 91.68  |   95.61   | 88.05  |
# +------------+-------+-------+--------+-----------+--------+
# 03/20 02:20:33 - mmengine - INFO - Iter(test) [956/956]    aAcc: 99.3200  mIoU: 85.3700  mAcc: 90.2200  mFscore: 91.9400  mPrecision: 93.8600  mRecall: 90.2200  data_time: 0.0427  time: 0.0622
# wandb: Currently logged in as: toqi. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.16.3
# wandb: Run data is saved locally in d:\toqi\codes\MethaneGas\models\mmseg\segformer\exp_4\work_dirs\20240320_021920\vis_data\wandb\run-20240320_021930-vnupgmq6
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Exp_3_DV7_mIoU
# wandb:  View project at https://wandb.ai/toqi/methane-segmentation
# wandb:  View run at https://wandb.ai/toqi/methane-segmentation/runs/vnupgmq6
# d:\toqi\opt\mmsegmentation\mmseg\models\builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# d:\toqi\opt\mmsegmentation\mmseg\models\losses\cross_entropy_loss.py:250: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# wandb: - 3.267 MB of 3.267 MB uploaded (0.015 MB deduped)
# wandb: \ 3.333 MB of 3.357 MB uploaded (0.019 MB deduped)
# wandb: | 3.341 MB of 3.357 MB uploaded (0.019 MB deduped)
# wandb: / 3.341 MB of 3.357 MB uploaded (0.019 MB deduped)
# wandb: - 3.357 MB of 3.357 MB uploaded (0.019 MB deduped)
# wandb:
# wandb:  View run Exp_3_DV7_mIoU at: https://wandb.ai/toqi/methane-segmentation/runs/vnupgmq6
# wandb:  View job at https://wandb.ai/toqi/methane-segmentation/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjEzOTIwNDUxMQ==/version_details/v62
# wandb: Synced 5 W&B file(s), 19 media file(s), 7 artifact file(s) and 0 other file(s)
# wandb: Find logs at: .\work_dirs\20240320_021920\vis_data\wandb\run-20240320_021930-vnupgmq6\logs

# %%
# !python ../../../../../../opt/mmsegmentation/tools/analysis_tools/confusion_matrix.py \
segformer_mit-b0_8xb2-160k_methane-512x512.py \
results/test_images \
results/confusion_matrix \
--show
# Out:
# [                                                  ] 0/956, elapsed: 0s, ETA:
# [                                ] 1/956, 63.9 task/s, elapsed: 0s, ETA:    15s
# [                                ] 2/956, 61.8 task/s, elapsed: 0s, ETA:    15s
# [                                ] 3/956, 89.8 task/s, elapsed: 0s, ETA:    11s
# [                               ] 4/956, 119.7 task/s, elapsed: 0s, ETA:     8s
# [                               ] 5/956, 102.0 task/s, elapsed: 0s, ETA:     9s
# [                                ] 6/956, 96.4 task/s, elapsed: 0s, ETA:    10s
# [                               ] 7/956, 112.4 task/s, elapsed: 0s, ETA:     8s
# [                               ] 8/956, 102.7 task/s, elapsed: 0s, ETA:     9s
# [                                ] 9/956, 99.5 task/s, elapsed: 0s, ETA:    10s
# [                              ] 10/956, 106.7 task/s, elapsed: 0s, ETA:     9s
# [                              ] 11/956, 117.4 task/s, elapsed: 0s, ETA:     8s
# [                              ] 12/956, 109.7 task/s, elapsed: 0s, ETA:     9s
# [                              ] 13/956, 118.9 task/s, elapsed: 0s, ETA:     8s
# [                              ] 14/956, 107.2 task/s, elapsed: 0s, ETA:     9s
# [                              ] 15/956, 113.5 task/s, elapsed: 0s, ETA:     8s
# [                              ] 16/956, 108.2 task/s, elapsed: 0s, ETA:     9s
# [                              ] 17/956, 108.9 task/s, elapsed: 0s, ETA:     9s
# [                              ] 18/956, 115.3 task/s, elapsed: 0s, ETA:     8s
# [                              ] 19/956, 110.6 task/s, elapsed: 0s, ETA:     8s
# [                              ] 20/956, 116.4 task/s, elapsed: 0s, ETA:     8s
# [                              ] 21/956, 110.2 task/s, elapsed: 0s, ETA:     8s
# [                              ] 22/956, 115.4 task/s, elapsed: 0s, ETA:     8s
# [                              ] 23/956, 120.7 task/s, elapsed: 0s, ETA:     8s
# [                              ] 24/956, 116.4 task/s, elapsed: 0s, ETA:     8s
# [                              ] 25/956, 114.3 task/s, elapsed: 0s, ETA:     8s
# [                              ] 26/956, 118.9 task/s, elapsed: 0s, ETA:     8s
# [                              ] 27/956, 115.2 task/s, elapsed: 0s, ETA:     8s
# [                              ] 28/956, 119.5 task/s, elapsed: 0s, ETA:     8s
# [                              ] 29/956, 114.1 task/s, elapsed: 0s, ETA:     8s
# [                              ] 30/956, 118.1 task/s, elapsed: 0s, ETA:     8s
# [                              ] 31/956, 114.9 task/s, elapsed: 0s, ETA:     8s
# [>                             ]
mmsegmentation\mmseg\models\builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# d:\toqi\opt\mmsegmentation\mmseg\models\losses\cross_entropy_loss.py:250: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(

# %%
# !python ../../../../../../opt/mmsegmentation/tools/analysis_tools/benchmark_cpu.py \
segformer_mit-b0_8xb2-160k_methane-512x512.py \
work_dirs/best_mIoU_iter_160000.pth
# Out:
# Run 1:
# Loads checkpoint by local backend from path: work_dirs/best_mIoU_iter_160000.pth
# Done image [50 / 200], fps: 3.57 img / s
# Done image [100/ 200], fps: 3.55 img / s
# Done image [150/ 200], fps: 3.55 img / s
# Done image [200/ 200], fps: 3.55 img / s
# Overall fps: 3.55 img / s
#
# Average fps of 1 evaluations: 3.55
# The variance of 1 evaluations: 0.0
# d:\toqi\opt\mmsegmentation\mmseg\models\builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# d:\toqi\opt\mmsegmentation\mmseg\models\losses\cross_entropy_loss.py:250: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(

# %%
# !python ../../../../../../opt/mmsegmentation/tools/analysis_tools/get_flops.py segformer_mit-b0_8xb2-160k_methane-512x512.py --shape 640 480
# Out:
# 03/20 02:22:52 - mmengine - WARNING - Unsupported operator aten::div encountered 16 time(s)
# 03/20 02:22:52 - mmengine - WARNING - Unsupported operator aten::mul encountered 48 time(s)
# 03/20 02:22:52 - mmengine - WARNING - Unsupported operator aten::unflatten encountered 8 time(s)
# 03/20 02:22:52 - mmengine - WARNING - Unsupported operator aten::softmax encountered 8 time(s)
# 03/20 02:22:52 - mmengine - WARNING - Unsupported operator aten::add encountered 16 time(s)
# 03/20 02:22:52 - mmengine - WARNING - Unsupported operator aten::gelu encountered 8 time(s)
# 03/20 02:22:52 - mmengine - WARNING - Unsupported operator aten::feature_dropout encountered 1 time(s)
# 03/20 02:22:52 - mmengine - WARNING - The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# backbone.layers.0.1.0.attn.attn.out_proj, backbone.layers.0.1.0.attn.dropout_layer, backbone.layers.0.1.0.ffn.dropout_layer, backbone.layers.0.1.1.attn.attn.out_proj, backbone.layers.0.1.1.attn.dropout_layer, backbone.layers.0.1.1.ffn.dropout_layer, backbone.layers.1.1.0.attn.attn.out_proj, backbone.layers.1.1.0.attn.dropout_layer, backbone.layers.1.1.0.ffn.dropout_layer, backbone.layers.1.1.1.attn.attn.out_proj, backbone.layers.1.1.1.attn.dropout_layer, backbone.layers.1.1.1.ffn.dropout_layer, backbone.layers.2.1.0.attn.attn.out_proj, backbone.layers.2.1.0.attn.dropout_layer, backbone.layers.2.1.0.ffn.dropout_layer, backbone.layers.2.1.1.attn.attn.out_proj, backbone.layers.2.1.1.attn.dropout_layer, backbone.layers.2.1.1.ffn.dropout_layer, backbone.layers.3.1.0.attn.attn.out_proj, backbone.layers.3.1.0.attn.dropout_layer, backbone.layers.3.1.0.ffn.dropout_layer, backbone.layers.3.1.1.attn.attn.out_proj, backbone.layers.3.1.1.attn.dropout_layer, backbone.layers.3.1.1.ffn.dropout_layer, data_preprocessor, decode_head.loss_decode
# 03/20 02:22:53 - mmengine - WARNING - Unsupported operator aten::layer_norm encountered 30 time(s)
# 03/20 02:22:53 - mmengine - WARNING - Unsupported operator aten::batch_norm encountered 5 time(s)
# 03/20 02:22:53 - mmengine - WARNING - Unsupported operator aten::upsample_bilinear2d encountered 4 time(s)
# ==============================
# Compute type: direct: randomly generate a picture
# Input shape: (640, 480)
# Flops: 9.494G
# Params: 3.718M
# ==============================
# !!!Please be cautious if you use the results in papers. You may need to check if all ops are supported and verify that the flops computation is correct.
# d:\toqi\opt\mmsegmentation\mmseg\models\builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# d:\toqi\opt\mmsegmentation\mmseg\models\losses\cross_entropy_loss.py:250: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(

# %%
# !python ../../../../../../opt/mmsegmentation/tools/test.py segformer_mit-b0_8xb2-160k_methane-512x512.py work_dirs/best_mIoU_iter_160000.pth --work-dir work_dirs --show-dir inference --tta
# Out:
# 03/20 02:23:00 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: win32
#     Python: 3.10.13 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:24:38) [MSC v.1916 64 bit (AMD64)]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 202437086
#     GPU 0: NVIDIA GeForce RTX 3090
#     CUDA_HOME: C:/Program Files/NVIDIA GPU Computing Toolkit/CUDA\v11.6
#     NVCC: Cuda compilation tools, release 11.6, V11.6.55
#     MSVC: Microsoft (R) C/C++ Optimizing Compiler Version 19.29.30137 for x64
#     GCC: n/a
#     PyTorch: 2.2.0
#     PyTorch compiling details: PyTorch built with:
#   - C++ Version: 201703
#   - MSVC 192930151
#   - Intel(R) Math Kernel Library Version 2020.0.2 Product Build 20200624 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.2 (Git Hash 2dc95a2ad0841e29db8b22fbccaf3e5da7992b01)
#   - OpenMP 2019
#   - LAPACK is enabled (usually provided by MKL)
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_90,code=sm_90;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.7
#   - Magma 2.5.4
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=C:/cb/pytorch_1000000000000/work/tmp_bin/sccache-cl.exe, CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /Zc:__cplusplus /bigobj /FS /utf-8 -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE /wd4624 /wd4068 /wd4067 /wd4267 /wd4661 /wd4717 /wd4244 /wd4804 /wd4273, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.2.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.17.0
#     OpenCV: 4.9.0
#     MMEngine: 0.10.3
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 202437086
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 03/20 02:23:01 - mmengine - INFO - Config:
# checkpoint = 'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segformer/mit_b0_20220624-7e0fe6dd.pth'
# crop_size = (
#     512,
#     512,
# )
# data_preprocessor = dict(
#     bgr_to_rgb=True,
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     pad_val=0,
#     seg_pad_val=255,
#     size=(
#         512,
#         512,
#     ),
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     type='SegDataPreProcessor')
# data_root = '../../../../data/V7/'
# dataset_type = 'MethaneDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         by_epoch=False,
#         interval=16000,
#         max_keep_ckpts=2,
#         save_best='mIoU',
#         type='CheckpointHook'),
#     logger=dict(interval=50, log_metric_by_epoch=False, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(draw=True, type='SegVisualizationHook'))
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# img_ratios = [
#     0.5,
#     0.75,
#     1.0,
#     1.25,
#     1.5,
#     1.75,
# ]
# img_scale = (
#     640,
#     480,
# )
# launcher = 'none'
# load_from = 'work_dirs/best_mIoU_iter_160000.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=False)
# model = dict(
#     module=dict(
#         backbone=dict(
#             attn_drop_rate=0.0,
#             drop_path_rate=0.1,
#             drop_rate=0.0,
#             embed_dims=32,
#             in_channels=3,
#             init_cfg=dict(
#                 checkpoint=
#                 'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segformer/mit_b0_20220624-7e0fe6dd.pth',
#                 type='Pretrained'),
#             mlp_ratio=4,
#             num_heads=[
#                 1,
#                 2,
#                 5,
#                 8,
#             ],
#             num_layers=[
#                 2,
#                 2,
#                 2,
#                 2,
#             ],
#             num_stages=4,
#             out_indices=(
#                 0,
#                 1,
#                 2,
#                 3,
#             ),
#             patch_sizes=[
#                 7,
#                 3,
#                 3,
#                 3,
#             ],
#             qkv_bias=True,
#             sr_ratios=[
#                 8,
#                 4,
#                 2,
#                 1,
#             ],
#             type='MixVisionTransformer'),
#         data_preprocessor=dict(
#             bgr_to_rgb=True,
#             mean=[
#                 123.675,
#                 116.28,
#                 103.53,
#             ],
#             pad_val=0,
#             seg_pad_val=255,
#             size=(
#                 512,
#                 512,
#             ),
#             std=[
#                 58.395,
#                 57.12,
#                 57.375,
#             ],
#             type='SegDataPreProcessor'),
#         decode_head=dict(
#             align_corners=False,
#             channels=256,
#             dropout_ratio=0.1,
#             in_channels=[
#                 32,
#                 64,
#                 160,
#                 256,
#             ],
#             in_index=[
#                 0,
#                 1,
#                 2,
#                 3,
#             ],
#             loss_decode=dict(
#                 loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#             norm_cfg=dict(requires_grad=True, type='SyncBN'),
#             num_classes=11,
#             type='SegformerHead'),
#         pretrained=None,
#         test_cfg=dict(mode='whole'),
#         train_cfg=dict(),
#         type='EncoderDecoder'),
#     type='SegTTAModel')
# norm_cfg = dict(requires_grad=True, type='SyncBN')
# optim_wrapper = dict(
#     optimizer=dict(
#         betas=(
#             0.9,
#             0.999,
#         ), lr=6e-05, type='AdamW', weight_decay=0.01),
#     paramwise_cfg=dict(
#         custom_keys=dict(
#             head=dict(lr_mult=10.0),
#             norm=dict(decay_mult=0.0),
#             pos_block=dict(decay_mult=0.0))),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=1500, start_factor=1e-06,
#         type='LinearLR'),
#     dict(
#         begin=1500,
#         by_epoch=False,
#         end=160000,
#         eta_min=0.0,
#         power=1.0,
#         type='PolyLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(
#             img_path='test/images', seg_map_path='test/mmseg_masks'),
#         data_root='../../../../data/V7/',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(
#                 transforms=[
#                     [
#                         dict(keep_ratio=True, scale_factor=0.5, type='Resize'),
#                         dict(
#                             keep_ratio=True, scale_factor=0.75, type='Resize'),
#                         dict(keep_ratio=True, scale_factor=1.0, type='Resize'),
#                         dict(
#                             keep_ratio=True, scale_factor=1.25, type='Resize'),
#                         dict(keep_ratio=True, scale_factor=1.5, type='Resize'),
#                         dict(
#                             keep_ratio=True, scale_factor=1.75, type='Resize'),
#                     ],
#                     [
#                         dict(
#                             direction='horizontal',
#                             prob=1.0,
#                             type='RandomFlip'),
#                     ],
#                     [
#                         dict(type='LoadAnnotations'),
#                     ],
#                     [
#                         dict(type='PackSegInputs'),
#                     ],
#                 ],
#                 type='TestTimeAug'),
#         ],
#         type='MethaneDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#         'mFscore',
#     ], type='IoUMetric')
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         640,
#         480,
#     ), type='Resize'),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs'),
# ]
# train_cfg = dict(
#     max_iters=160000, type='IterBasedTrainLoop', val_interval=16000)
# train_dataloader = dict(
#     batch_size=2,
#     dataset=dict(
#         data_prefix=dict(
#             img_path='train/images', seg_map_path='train/mmseg_masks'),
#         data_root='../../../../data/V7/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     0.5,
#                     2.0,
#                 ),
#                 scale=(
#                     640,
#                     480,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 cat_max_ratio=0.75, crop_size=(
#                     512,
#                     512,
#                 ), type='RandomCrop'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs'),
#         ],
#         type='MethaneDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='InfiniteSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             0.5,
#             2.0,
#         ),
#         scale=(
#             640,
#             480,
#         ),
#         type='RandomResize'),
#     dict(cat_max_ratio=0.75, crop_size=(
#         512,
#         512,
#     ), type='RandomCrop'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs'),
# ]
# tta_model = dict(
#     module=dict(
#         backbone=dict(
#             attn_drop_rate=0.0,
#             drop_path_rate=0.1,
#             drop_rate=0.0,
#             embed_dims=32,
#             in_channels=3,
#             init_cfg=dict(
#                 checkpoint=
#                 'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segformer/mit_b0_20220624-7e0fe6dd.pth',
#                 type='Pretrained'),
#             mlp_ratio=4,
#             num_heads=[
#                 1,
#                 2,
#                 5,
#                 8,
#             ],
#             num_layers=[
#                 2,
#                 2,
#                 2,
#                 2,
#             ],
#             num_stages=4,
#             out_indices=(
#                 0,
#                 1,
#                 2,
#                 3,
#             ),
#             patch_sizes=[
#                 7,
#                 3,
#                 3,
#                 3,
#             ],
#             qkv_bias=True,
#             sr_ratios=[
#                 8,
#                 4,
#                 2,
#                 1,
#             ],
#             type='MixVisionTransformer'),
#         data_preprocessor=dict(
#             bgr_to_rgb=True,
#             mean=[
#                 123.675,
#                 116.28,
#                 103.53,
#             ],
#             pad_val=0,
#             seg_pad_val=255,
#             size=(
#                 512,
#                 512,
#             ),
#             std=[
#                 58.395,
#                 57.12,
#                 57.375,
#             ],
#             type='SegDataPreProcessor'),
#         decode_head=dict(
#             align_corners=False,
#             channels=256,
#             dropout_ratio=0.1,
#             in_channels=[
#                 32,
#                 64,
#                 160,
#                 256,
#             ],
#             in_index=[
#                 0,
#                 1,
#                 2,
#                 3,
#             ],
#             loss_decode=dict(
#                 loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#             norm_cfg=dict(requires_grad=True, type='SyncBN'),
#             num_classes=11,
#             type='SegformerHead'),
#         pretrained=None,
#         test_cfg=dict(mode='whole'),
#         train_cfg=dict(),
#         type='EncoderDecoder'),
#     type='SegTTAModel')
# tta_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         transforms=[
#             [
#                 dict(keep_ratio=True, scale_factor=0.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=0.75, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.0, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.25, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.75, type='Resize'),
#             ],
#             [
#                 dict(direction='horizontal', prob=1.0, type='RandomFlip'),
#             ],
#             [
#                 dict(type='LoadAnnotations'),
#             ],
#             [
#                 dict(type='PackSegInputs'),
#             ],
#         ],
#         type='TestTimeAug'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(
#             img_path='validation/images',
#             seg_map_path='validation/mmseg_masks'),
#         data_root='../../../../data/V7/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 640,
#                 480,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='MethaneDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#         'mFscore',
#     ], type='IoUMetric')
# vis_backends = [
#     dict(save_dir='work_dirs', type='LocalVisBackend'),
#     dict(type='TensorboardVisBackend'),
#     dict(
#         init_kwargs=dict(
#             entity='toqi',
#             group='segformer',
#             name='Exp_3_DV7_mIoU',
#             project='methane-segmentation'),
#         type='WandbVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     save_dir='inference',
#     type='SegLocalVisualizer',
#     vis_backends=[
#         dict(save_dir='work_dirs', type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(
#             init_kwargs=dict(
#                 entity='toqi',
#                 group='segformer',
#                 name='Exp_3_DV7_mIoU',
#                 project='methane-segmentation'),
#             type='WandbVisBackend'),
#     ])
# work_dir = 'work_dirs'
#
# 03/20 02:23:10 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 03/20 02:23:10 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 03/20 02:23:12 - mmengine - WARNING - The prefix is not set in metric class IoUMetric.
# Loads checkpoint by local backend from path: work_dirs/best_mIoU_iter_160000.pth
# 03/20 02:23:13 - mmengine - INFO - Load checkpoint from work_dirs/best_mIoU_iter_160000.pth
# 03/20 02:23:44 - mmengine - INFO - Iter(test) [ 50/956]    eta: 0:06:47  time: 0.0886  data_time: 0.0044  memory: 1003
# 03/20 02:23:50 - mmengine - INFO - Iter(test) [100/956]    eta: 0:05:07  time: 0.0910  data_time: 0.0053  memory: 714
# 03/20 02:23:56 - mmengine - INFO - Iter(test) [150/956]    eta: 0:03:44  time: 0.0901  data_time: 0.0023  memory: 714
# 03/20 02:24:02 - mmengine - INFO - Iter(test) [200/956]    eta: 0:02:58  time: 0.0903  data_time: 0.0036  memory: 714
# 03/20 02:24:07 - mmengine - INFO - Iter(test) [250/956]    eta: 0:02:29  time: 0.0905  data_time: 0.0026  memory: 714
# 03/20 02:24:13 - mmengine - INFO - Iter(test) [300/956]    eta: 0:02:08  time: 0.0902  data_time: 0.0044  memory: 714
# 03/20 02:24:18 - mmengine - INFO - Iter(test) [350/956]    eta: 0:01:51  time: 0.0919  data_time: 0.0029  memory: 714
# 03/20 02:24:24 - mmengine - INFO - Iter(test) [400/956]    eta: 0:01:36  time: 0.0915  data_time: 0.0028  memory: 714
# 03/20 02:24:30 - mmengine - INFO - Iter(test) [450/956]    eta: 0:01:25  time: 0.0916  data_time: 0.0063  memory: 714
# 03/20 02:24:36 - mmengine - INFO - Iter(test) [500/956]    eta: 0:01:14  time: 0.0927  data_time: 0.0041  memory: 714
# 03/20 02:24:41 - mmengine - INFO - Iter(test) [550/956]    eta: 0:01:04  time: 0.0953  data_time: 0.0033  memory: 714
# 03/20 02:24:47 - mmengine - INFO - Iter(test) [600/956]    eta: 0:00:55  time: 0.1020  data_time: 0.0062  memory: 714
# 03/20 02:24:53 - mmengine - INFO - Iter(test) [650/956]    eta: 0:00:46  time: 0.0971  data_time: 0.0025  memory: 714
# 03/20 02:24:59 - mmengine - INFO - Iter(test) [700/956]    eta: 0:00:38  time: 0.0972  data_time: 0.0027  memory: 714
# 03/20 02:25:05 - mmengine - INFO - Iter(test) [750/956]    eta: 0:00:30  time: 0.0942  data_time: 0.0054  memory: 714
# 03/20 02:25:11 - mmengine - INFO - Iter(test) [800/956]    eta: 0:00:22  time: 0.0945  data_time: 0.0050  memory: 714
# 03/20 02:25:17 - mmengine - INFO - Iter(test) [850/956]    eta: 0:00:15  time: 0.0931  data_time: 0.0022  memory: 714
# 03/20 02:25:23 - mmengine - INFO - Iter(test) [900/956]    eta: 0:00:07  time: 0.0942  data_time: 0.0036  memory: 714
# 03/20 02:25:28 - mmengine - INFO - Iter(test) [950/956]    eta: 0:00:00  time: 0.0931  data_time: 0.0046  memory: 714
# 03/20 02:25:29 - mmengine - INFO - per class results:
# 03/20 02:25:29 - mmengine - INFO -
# +------------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  | Fscore | Precision | Recall |
# +------------+-------+-------+--------+-----------+--------+
# | background | 99.15 |  99.6 | 99.57  |   99.55   |  99.6  |
# |     10     | 54.33 | 59.38 |  70.4  |   86.45   | 59.38  |
# |     20     | 76.69 |  79.5 | 86.81  |   95.59   |  79.5  |
# |     30     | 79.23 | 81.82 | 88.41  |   96.16   | 81.82  |
# |     40     | 81.61 | 91.95 | 89.87  |   87.89   | 91.95  |
# |     50     | 81.32 | 92.69 |  89.7  |   86.89   | 92.69  |
# |     60     | 84.44 | 89.82 | 91.56  |   93.37   | 89.82  |
# |     70     |  87.9 | 94.22 | 93.56  |    92.9   | 94.22  |
# |     80     | 87.62 | 93.96 |  93.4  |   92.85   | 93.96  |
# |     90     | 86.46 | 92.36 | 92.74  |   93.11   | 92.36  |
# |    100     | 83.93 | 89.36 | 91.26  |   93.25   | 89.36  |
# +------------+-------+-------+--------+-----------+--------+
# 03/20 02:25:29 - mmengine - INFO - Iter(test) [956/956]    aAcc: 99.1900  mIoU: 82.0600  mAcc: 87.7000  mFscore: 89.7500  mPrecision: 92.5500  mRecall: 87.7000  data_time: 0.0477  time: 0.1419
# wandb: Currently logged in as: toqi. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.16.3
# wandb: Run data is saved locally in inference\vis_data\wandb\run-20240320_022307-99cfhog9
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Exp_3_DV7_mIoU
# wandb:  View project at https://wandb.ai/toqi/methane-segmentation
# wandb:  View run at https://wandb.ai/toqi/methane-segmentation/runs/99cfhog9
# d:\toqi\opt\mmsegmentation\mmseg\models\builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# d:\toqi\opt\mmsegmentation\mmseg\models\losses\cross_entropy_loss.py:250: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# c:\Users\SIU856562106\AppData\Local\miniconda3\envs\mmlab\lib\site-packages\mmengine\structures\pixel_data.py:83: UserWarning: The shape of value will convert from torch.Size([480, 640]) to torch.Size([1, 480, 640])
#   warnings.warn('The shape of value will convert from '
# c:\Users\SIU856562106\AppData\Local\miniconda3\envs\mmlab\lib\site-packages\mmengine\structures\pixel_data.py:83: UserWarning: The shape of value will convert from torch.Size([480, 640]) to torch.Size([1, 480, 640])
#   warnings.warn('The shape of value will convert from '
# wandb: - 3.266 MB of 3.266 MB uploaded (0.015 MB deduped)
# wandb: \ 3.349 MB of 3.376 MB uploaded (0.019 MB deduped)
# wandb: | 3.357 MB of 3.376 MB uploaded (0.019 MB deduped)
# wandb: / 3.357 MB of 3.376 MB uploaded (0.019 MB deduped)
# wandb: - 3.376 MB of 3.376 MB uploaded (0.019 MB deduped)
# wandb:
# wandb:  View run Exp_3_DV7_mIoU at: https://wandb.ai/toqi/methane-segmentation/runs/99cfhog9
# wandb:  View job at https://wandb.ai/toqi/methane-segmentation/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjEzOTIwNDUxMQ==/version_details/v63
# wandb: Synced 5 W&B file(s), 19 media file(s), 7 artifact file(s) and 0 other file(s)
# wandb: Find logs at: inference\vis_data\wandb\run-20240320_022307-99cfhog9\logs
